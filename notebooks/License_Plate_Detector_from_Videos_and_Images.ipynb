# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi04092004/LicenseDetectorModel/blob/main/License_Plate_Detector_from_Videos_and_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Apr 14 05:22:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20338, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 20338 (delta 1), reused 0 (delta 0), pack-reused 20335 (from 2)
# Receiving objects: 100% (20338/20338), 11.11 MiB | 13.62 MiB/s, done.
# Resolving deltas: 100% (14353/14353), done.

# %%
# %cd yolov10
# Out:
# /content/yolov10

# %%
# !pwd
# Out:
# /content/yolov10

# %%
# !pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.2 MB/s eta 0:00:00
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/yolov10/weights/yolov10n.pt
# Downloaded /content/yolov10/weights/yolov10s.pt
# Downloaded /content/yolov10/weights/yolov10m.pt
# Downloaded /content/yolov10/weights/yolov10b.pt
# Downloaded /content/yolov10/weights/yolov10x.pt

# %%
# !unzip license_plate.zip
# Out:
# Archive:  license_plate.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/03o6p96xjmka1_jpg.rf.249ad01b00296fb27381382659664d84.jpg
#  extracting: test/images/03o6p96xjmka1_jpg.rf.bd2200401ece9c2b69eb84495bf21f59.jpg
#  extracting: test/images/04916a30e99034bb2_jpg.rf.1a6cbaec421045a7322b68a9b80b0e99.jpg
#  extracting: test/images/04916a30e99034bb2_jpg.rf.33943c473f07638bd397beb82aeb05da.jpg
#  extracting: test/images/0818ee8c-a6c0-4714-b585-6caa812fe645_jpg.rf.43c441191335cbde84742b2a8db3ab4e.jpg
#  extracting: test/images/0818ee8c-a6c0-4714-b585-6caa812fe645_jpg.rf.4439110cd4223f1480920738d7948aca.jpg
#  extracting: test/images/089e691c-f60e-4f0d-8223-a96169d5dd7e_jpg.rf.f5348d53b70f3723536af47f807a4347.jpg
#  extracting: test/images/09baf532-0c1b-4170-bff9-7d48d8f4b1a2_jpg.rf.d845fcdd4fd6006815b6c4ef3582f9c0.jpg
# ...

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=weights/yolov10n.pt data=data.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=car.jpg
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 125 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 /content/yolov10/car.jpg: 384x640 2 license-plates, 41.1ms
# Speed: 3.3ms preprocess, 41.1ms inference, 24.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=video.mp4
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 125 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/930) /content/yolov10/video.mp4: 384x640 (no detections), 57.1ms
# video 1/1 (frame 2/930) /content/yolov10/video.mp4: 384x640 (no detections), 18.0ms
# video 1/1 (frame 3/930) /content/yolov10/video.mp4: 384x640 (no detections), 17.4ms
# video 1/1 (frame 4/930) /content/yolov10/video.mp4: 384x640 (no detections), 19.5ms
# video 1/1 (frame 5/930) /content/yolov10/video.mp4: 384x640 (no detections), 15.3ms
# video 1/1 (frame 6/930) /content/yolov10/video.mp4: 384x640 (no detections), 17.6ms
# video 1/1 (frame 7/930) /content/yolov10/video.mp4: 384x640 (no detections), 13.4ms
# video 1/1 (frame 8/930) /content/yolov10/video.mp4: 384x640 (no detections), 14.0ms
# video 1/1 (frame 9/930) /content/yolov10/video.mp4: 384x640 (no detections), 12.1ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=video2.mp4
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 125 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/497) /content/yolov10/video2.mp4: 384x640 (no detections), 41.2ms
# video 1/1 (frame 2/497) /content/yolov10/video2.mp4: 384x640 (no detections), 13.3ms
# video 1/1 (frame 3/497) /content/yolov10/video2.mp4: 384x640 (no detections), 16.5ms
# video 1/1 (frame 4/497) /content/yolov10/video2.mp4: 384x640 (no detections), 12.1ms
# video 1/1 (frame 5/497) /content/yolov10/video2.mp4: 384x640 (no detections), 13.5ms
# video 1/1 (frame 6/497) /content/yolov10/video2.mp4: 384x640 (no detections), 13.0ms
# video 1/1 (frame 7/497) /content/yolov10/video2.mp4: 384x640 (no detections), 12.3ms
# video 1/1 (frame 8/497) /content/yolov10/video2.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (frame 9/497) /content/yolov10/video2.mp4: 384x640 (no detections), 17.4ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r runs /content/drive/MyDrive/YOLO_MODELS/
